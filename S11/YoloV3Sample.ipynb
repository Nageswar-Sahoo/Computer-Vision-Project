# %% [markdown]
# <a href="https://colab.research.google.com/github/Nageswar-Sahoo/Computer-Vision-Project/blob/main/S11/YoloV3Sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Nageswar-Sahoo/Computer-Vision-Project.git
# Out:
# Cloning into 'Computer-Vision-Project'...
# remote: Enumerating objects: 8680, done.
# remote: Counting objects: 100% (8680/8680), done.
# remote: Compressing objects: 100% (8309/8309), done.
# remote: Total 8680 (delta 910), reused 7855 (delta 269), pack-reused 0
# Receiving objects: 100% (8680/8680), 286.73 MiB | 14.12 MiB/s, done.
# Resolving deltas: 100% (910/910), done.
# Checking out files: 100% (14836/14836), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp YOLOV3_Weight/yolov3-spp-ultralytics.pt Computer-Vision-Project/YOLOV3/weights

# %%
ls Computer-Vision-Project/YOLOV3/weights
# Out:
# ex  yolov3-spp-ultralytics.pt

# %%
cd  /content/gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
ls
# Out:
# 'Colab Notebooks'/         'Untitled document (1).gdoc'
#  Computer-Vision-Project/  'Untitled document (2).gdoc'
#  results.txt               'Untitled document.gdoc'
#  test_batch0.png            YOLOV3_Weight/

# %%
cd Computer-Vision-Project/YOLOV3/
# Out:
# /content/gdrive/MyDrive/Computer-Vision-Project/YOLOV3

# %%
rm -rf  /content/gdrive/MyDrive/Computer-Vision-Project/

# %%
# !ls
# Out:
#  cfg	     output	    results.png       test.py	       utils
#  data	     __pycache__    results.txt       ting	       weights
#  detect.py   README.md	    runs	      train.py
#  models.py   results.json   test_batch0.png  'ubdivisions=1'

# %%
# !git pull
# Out:
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.
# From https://github.com/Nageswar-Sahoo/Computer-Vision-Project
#    d85e8e5..392185b  main       -> origin/main
# Updating d85e8e5..392185b
# ^C

# %%
https://github.com/Nageswar-Sahoo/Computer-Vision-Project.git

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.10.0+cu111 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   results.json      ting	        vim.exe.stackdump
#  cfg		   results.png	     train_batch0.png   weights
#  data		   results.txt	     train.py
#  models.py	   test_batch0.png  'ubdivisions=1'
#  __pycache__	   test.py	     utils

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-17 15:50:27.389103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 6747.05it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 129.73it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 2 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=2, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2939 found, 135 missing, 38 empty, 0 duplicate, for 3112 images): 100% 3112/3112 [00:06<00:00, 494.31it/s]
# Caching images (1.7GB): 100% 3112/3112 [00:43<00:00, 70.74it/s]
# Reading image shapes: 100% 325/325 [00:00<00:00, 442.90it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 4 --nosave --resume
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=4, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=True, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2939 found, 135 missing, 38 empty, 0 duplicate, for 3112 images): 100% 3112/3112 [00:05<00:00, 613.24it/s]
# Caching images (1.7GB): 100% 3112/3112 [00:36<00:00, 84.49it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 20 --nosave --resume --cache-images
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=20, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=True, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2939 found, 135 missing, 38 empty, 0 duplicate, for 3112 images): 100% 3112/3112 [16:03<00:00,  3.23it/s]
# Caching images (1.7GB): 100% 3112/3112 [17:36<00:00,  2.95it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 70 --nosave --resume --cache-images
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=70, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=True, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2939 found, 135 missing, 38 empty, 0 duplicate, for 3112 images): 100% 3112/3112 [11:00<00:00,  4.71it/s]
# Caching images (1.7GB): 100% 3112/3112 [12:18<00:00,  4.22it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 130 --nosave --resume --cache-images
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=130, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=True, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2939 found, 135 missing, 38 empty, 0 duplicate, for 3112 images): 100% 3112/3112 [00:03<00:00, 818.97it/s]
# Caching images (1.7GB): 100% 3112/3112 [00:33<00:00, 92.58it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 170 --nosave --resume --cache-images
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=170, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=True, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2939 found, 135 missing, 38 empty, 0 duplicate, for 3112 images): 100% 3112/3112 [01:18<00:00, 39.81it/s]
# Caching images (1.7GB): 100% 3112/3112 [00:33<00:00, 94.07it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 180 --nosave --resume --cache-images
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=180, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=True, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2939 found, 135 missing, 38 empty, 0 duplicate, for 3112 images): 100% 3112/3112 [00:03<00:00, 816.02it/s]
# Caching images (1.7GB): 100% 3112/3112 [00:32<00:00, 95.53it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 200 --nosave --resume --cache-images
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=200, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=True, single_cls=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2939 found, 135 missing, 38 empty, 0 duplicate, for 3112 images): 100% 3112/3112 [00:03<00:00, 844.38it/s]
# Caching images (1.7GB): 100% 3112/3112 [00:32<00:00, 96.32it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --source data/customdata/myimage --output output/myimage
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output/myimage', save_txt=False, source='data/customdata/myimage', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/97 data/customdata/myimage/1-best-hi-vis-hard-hat-lift-min.jpg: 512x384 1 hardhats, Done. (0.021s)
# ...

# %%
# !python detect.py --conf-thres 0.1 --source data/customdata/video1 --output output/video1
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output/video1', save_txt=False, source='data/customdata/video1', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/61 data/customdata/video1/out1.png: 320x512 Done. (0.019s)
# image 2/61 data/customdata/video1/out10.png: 320x512 Done. (0.017s)
# ...

# %%
# !python detect.py --conf-thres 0.1 --source data/customdata/video2 --output output/video2
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output/video2', save_txt=False, source='data/customdata/video2', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/10 data/customdata/video2/out1.png: 384x512 Done. (0.021s)
# image 2/10 data/customdata/video2/out10.png: 384x512 Done. (0.015s)
# ...
